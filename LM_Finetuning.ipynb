# %% [markdown]
# #### We finetune this LM : roberta-base-squad2 on dataset.txt having question and answer

# %%
from transformers import RobertaForQuestionAnswering, RobertaTokenizer, RobertaTokenizerFast
import pickle
import random
import torch
from torch.utils.data import Dataset

# %%
# Get data from LM Dataset.txt
questions = []
answers = []
with open('LM_dataset.txt', 'r') as file:
    lines = file.readlines()
    for i, line in enumerate(lines):
        if i % 3 == 0:
            questions.append(line.strip())
        elif i % 3 == 1:
            answers.append(line.strip()[8:])
        else:
            continue

# %%
# Read graph for context
with open('graph.pkl', 'rb') as f:
    graph = pickle.load(f)

# %%
# Helper function to create context 
def get_context_from_qa(graph, ques, ans):
    ques = ques.lower()
    ans = ans.lower()
    context = [ans]
    for node in graph.nodes():
        if node in ques and node is not None:
            context.append(node)
    random.shuffle(context)
    return ' '.join(context)

# %%
# Create dataset in standard QA format
dataset = []
for i in range(len(questions)):
    sample = {}
    sample['question'] = str(questions[i])
    sample['context'] = get_context_from_qa(graph, questions[i], answers[i])
    text = str(answers[i].lower())
    answer= {}
    answer['text'] = [text]
    answer['answer_start'] = [sample['context'].find(text)] 
    sample['answer'] = answer 
    dataset.append(sample)

# %%
dataset
# Out:
# [{'question': 'In which year was the movie "Interstellar" with Matthew McConaughey released?',
#   'context': 'interstellar 2014 it matthew mcconaughey',
#   'answer': {'text': ['2014'], 'answer_start': [13]}},
#  {'question': 'Identify a 2015 film starring Jennifer Lawrence.',
#   'context': 'jennifer lawrence the hunger games: mockingjay - part 2 2015 ti',
#   'answer': {'text': ['the hunger games: mockingjay - part 2'],
#    'answer_start': [18]}},
#  {'question': 'Name a movie released in 2013 with Christian Bale in the lead role.',
#   'context': 'it ti 2013 american hustle christian bale',
#   'answer': {'text': ['american hustle'], 'answer_start': [11]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "Deadpool"?',
#   'context': 'deadpool 2016 deadpool it ti',
#   'answer': {'text': ['deadpool'], 'answer_start': [0]}},
#  {'question': 'Which film stars Leonardo DiCaprio and was released in 2015?',
#   'context': '2015 rio leonardo dicaprio the revenant',
#   'answer': {'text': ['the revenant'], 'answer_start': [27]}},
#  {'question': 'What is the title of the 2014 movie featuring Scarlett Johansson?',
#   'context': 'scarlett johansson it ti lucy 2014',
#   'answer': {'text': ['lucy'], 'answer_start': [25]}},
#  {'question': 'Which 2016 movie stars Henry Cavill and Ben Affleck?',
#   'context': 'henry cavill batman v superman: dawn of justice ben affleck 2016',
#   'answer': {'text': ['batman v superman: dawn of justice'],
#    'answer_start': [13]}},
#  {'question': 'In which year was the movie "The Martian" with Matt Damon released?',
#   'context': 'matt damon the martian 2015 ti it',
#   'answer': {'text': ['2015'], 'answer_start': [23]}},
#  {'question': 'Identify a film from 2013 that stars Sandra Bullock.',
#   'context': 'gravity 2013 sandra bullock ti',
#   'answer': {'text': ['gravity'], 'answer_start': [0]}},
#  {'question': 'Name a 2013 release with Hugh Jackman as the lead actor.',
#   'context': '2013 hugh jackman it the wolverine',
#   'answer': {'text': ['the wolverine'], 'answer_start': [21]}},
#  {'question': 'Can you mention a 2012 movie with Anne Hathaway in the lead role?',
#   'context': 'ti anne hathaway it les misérables 2012',
#   'answer': {'text': ['les misérables'], 'answer_start': [20]}},
#  {'question': 'What is the title of the film from 2016 featuring Margot Robbie?',
#   'context': '2016 suicide squad margot robbie it argo ti',
#   'answer': {'text': ['suicide squad'], 'answer_start': [5]}},
#  {'question': 'Which 2014 movie stars Dwayne Johnson?',
#   'context': 'hercules 2014 dwayne johnson',
#   'answer': {'text': ['hercules'], 'answer_start': [0]}},
#  {'question': 'In which year was the movie "The Girl on the Train" released with Emily Blunt?',
#   'context': 'the girl on the train it emily blunt 2016',
#   'answer': {'text': ['2016'], 'answer_start': [37]}},
#  {'question': 'Identify a 2015 film starring Tom Hardy.',
#   'context': '2015 mad max: fury road tom hardy ti',
#   'answer': {'text': ['mad max: fury road'], 'answer_start': [5]}},
#  {'question': 'Name a movie from 2015 with Mark Ruffalo in a leading role.',
#   'context': 'spotlight 2015 it mark ruffalo',
#   'answer': {'text': ['spotlight'], 'answer_start': [0]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "Fantastic Beasts and Where to Find Them"?',
#   'context': '2016 her ti it fantastic beasts and where to find them fantastic beasts and where to find them',
#   'answer': {'text': ['fantastic beasts and where to find them'],
#    'answer_start': [15]}},
#  {'question': 'Which film stars Will Smith and was released in 2016?',
#   'context': 'it 2016 suicide squad will smith',
#   'answer': {'text': ['suicide squad'], 'answer_start': [8]}},
#  {'question': 'What is the title of the 2014 movie featuring Channing Tatum?',
#   'context': '2014 channing tatum jupiter ascending ti it',
#   'answer': {'text': ['jupiter ascending'], 'answer_start': [20]}},
#  {'question': 'Which 2016 movie stars Felicity Jones?',
#   'context': 'rogue one 2016 it felicity jones',
#   'answer': {'text': ['rogue one'], 'answer_start': [0]}},
#  {'question': 'In which year was the movie "Hacksaw Ridge" with Andrew Garfield released?',
#   'context': 'it 2016 hacksaw ridge andrew garfield',
#   'answer': {'text': ['2016'], 'answer_start': [3]}},
#  {'question': 'Identify a 2016 film starring Ryan Gosling.',
#   'context': 'la la land ryan gosling 2016 ti',
#   'answer': {'text': ['la la land'], 'answer_start': [0]}},
#  {'question': 'Name a movie released in 2014 with Jake Gyllenhaal in the lead role.',
#   'context': 'jake gyllenhaal nightcrawler it 2014',
#   'answer': {'text': ['nightcrawler'], 'answer_start': [16]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "Doctor Strange"?',
#   'context': 'ti doctor strange 2016 it doctor strange',
#   'answer': {'text': ['doctor strange'], 'answer_start': [3]}},
#  {'question': 'Which film stars Matthew McConaughey and was released in 2014?',
#   'context': 'matthew mcconaughey interstellar 2014',
#   'answer': {'text': ['interstellar'], 'answer_start': [20]}},
#  {'question': 'What is the title of the 2015 movie featuring Alicia Vikander?',
#   'context': '2015 it alicia vikander the danish girl ti',
#   'answer': {'text': ['the danish girl'], 'answer_start': [24]}},
#  {'question': 'Which 2016 movie stars Ben Affleck?',
#   'context': '2016 ben affleck the accountant',
#   'answer': {'text': ['the accountant'], 'answer_start': [17]}},
#  {'question': 'In which year was the movie "Captain America: Civil War" released with Chris Evans?',
#   'context': '2016 war it chris evans',
#   'answer': {'text': ['2016'], 'answer_start': [0]}},
#  {'question': 'Identify a film from 2016 that stars Tom Hanks.',
#   'context': 'ti 2016 tom hanks sully',
#   'answer': {'text': ['sully'], 'answer_start': [18]}},
#  {'question': 'Name a 2015 release with Brie Larson as the lead actress.',
#   'context': 'room brie larson 2015 it',
#   'answer': {'text': ['room'], 'answer_start': [0]}},
#  {'question': 'Can you mention a 2015 movie with Cate Blanchett in the lead role?',
#   'context': 'cate blanchett carol 2015 ti it',
#   'answer': {'text': ['carol'], 'answer_start': [15]}},
#  {'question': 'What is the title of the film from 2016 featuring Amy Adams?',
#   'context': 'amy adams 2016 arrival ti it',
#   'answer': {'text': ['arrival'], 'answer_start': [15]}},
#  {'question': 'Which 2016 movie stars Matthew McConaughey?',
#   'context': 'gold matthew mcconaughey 2016',
#   'answer': {'text': ['gold'], 'answer_start': [0]}},
#  {'question': 'In which year was the movie "The Nice Guys" released with Russell Crowe?',
#   'context': 'it the nice guys 2016 russell crowe',
#   'answer': {'text': ['2016'], 'answer_start': [17]}},
#  {'question': 'Identify a 2015 film starring Saoirse Ronan.',
#   'context': 'saoirse ronan brooklyn ti 2015',
#   'answer': {'text': ['brooklyn'], 'answer_start': [14]}},
#  {'question': 'Name a movie from 2015 with Michael Fassbender in a leading role.',
#   'context': 'michael fassbender steve jobs 2015 it',
#   'answer': {'text': ['steve jobs'], 'answer_start': [19]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "Zootopia"?',
#   'context': 'zootopia it ti 2016 zootopia',
#   'answer': {'text': ['zootopia'], 'answer_start': [0]}},
#  {'question': 'Which film stars Margot Robbie and was released in 2016?',
#   'context': '2016 suicide squad argo margot robbie',
#   'answer': {'text': ['suicide squad'], 'answer_start': [5]}},
#  {'question': 'What is the title of the 2016 movie featuring Will Smith?',
#   'context': 'will smith it 2016 ti suicide squad',
#   'answer': {'text': ['suicide squad'], 'answer_start': [22]}},
#  {'question': 'Which 2016 movie stars Tom Hanks?',
#   'context': 'inferno 2016 tom hanks',
#   'answer': {'text': ['inferno'], 'answer_start': [0]}},
#  {'question': 'In which year was the movie "Jason Bourne" with Matt Damon released?',
#   'context': 'it matt damon 2016 jason bourne',
#   'answer': {'text': ['2016'], 'answer_start': [14]}},
#  {'question': 'Identify a 2016 film starring Dev Patel.',
#   'context': '2016 ti lion dev patel',
#   'answer': {'text': ['lion'], 'answer_start': [8]}},
#  {'question': 'Name a movie released in 2016 with Amy Adams in the lead role.',
#   'context': 'amy adams it 2016 arrival',
#   'answer': {'text': ['arrival'], 'answer_start': [18]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "War Dogs"?',
#   'context': 'war dogs it war dogs ti 2016 war',
#   'answer': {'text': ['war dogs'], 'answer_start': [0]}},
#  {'question': 'Which film stars Emma Stone and was released in 2016?',
#   'context': '2016 la la land emma stone',
#   'answer': {'text': ['la la land'], 'answer_start': [5]}},
#  {'question': 'What is the title of the 2016 movie featuring Charlize Theron?',
#   'context': "charlize theron the huntsman: winter's war ti her 2016 it",
#   'answer': {'text': ["the huntsman: winter's war"], 'answer_start': [16]}},
#  {'question': 'Which 2016 movie stars Chris Pratt?',
#   'context': 'chris pratt 2016 passengers',
#   'answer': {'text': ['passengers'], 'answer_start': [17]}},
#  {'question': 'In which year was the movie "Star Trek Beyond" released with Chris Pine?',
#   'context': 'it chris pine star trek beyond star trek 2016',
#   'answer': {'text': ['2016'], 'answer_start': [41]}},
#  {'question': 'Identify a film from 2016 that stars Margot Robbie.',
#   'context': '2016 argo suicide squad margot robbie ti',
#   'answer': {'text': ['suicide squad'], 'answer_start': [10]}},
#  {'question': 'Name a 2016 release with Felicity Jones as the lead actress.',
#   'context': 'it 2016 rogue one felicity jones',
#   'answer': {'text': ['rogue one'], 'answer_start': [8]}},
#  {'question': 'Can you mention a 2016 movie with Will Smith in the lead role?',
#   'context': 'suicide squad it 2016 will smith ti',
#   'answer': {'text': ['suicide squad'], 'answer_start': [0]}},
#  {'question': 'What is the title of the film from 2016 featuring Ben Affleck?',
#   'context': 'ben affleck the accountant 2016 it ti',
#   'answer': {'text': ['the accountant'], 'answer_start': [12]}},
#  {'question': 'Which 2016 movie stars Henry Cavill?',
#   'context': '2016 batman v superman: dawn of justice henry cavill',
#   'answer': {'text': ['batman v superman: dawn of justice'],
#    'answer_start': [5]}},
#  {'question': 'In which year was the movie "Jackie" released with Natalie Portman?',
#   'context': 'natalie portman 2016 it jackie',
#   'answer': {'text': ['2016'], 'answer_start': [16]}},
#  {'question': 'Identify a 2016 film starring Matthew McConaughey.',
#   'context': '2016 matthew mcconaughey ti gold',
#   'answer': {'text': ['gold'], 'answer_start': [28]}},
#  {'question': 'Name a movie from 2016 with Ryan Reynolds in a leading role.',
#   'context': 'deadpool 2016 it ryan reynolds',
#   'answer': {'text': ['deadpool'], 'answer_start': [0]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "The Girl on the Train"?',
#   'context': '2016 it the girl on the train the girl on the train ti',
#   'answer': {'text': ['the girl on the train'], 'answer_start': [8]}},
#  {'question': 'Which film stars Jennifer Lawrence and was released in 2016?',
#   'context': 'jennifer lawrence passengers 2016',
#   'answer': {'text': ['passengers'], 'answer_start': [18]}},
#  {'question': 'What is the title of the 2016 movie featuring Eddie Redmayne?',
#   'context': 'ti fantastic beasts and where to find them 2016 red eddie redmayne it',
#   'answer': {'text': ['fantastic beasts and where to find them'],
#    'answer_start': [3]}},
#  {'question': 'Which 2016 movie stars Will Smith and Jared Leto?',
#   'context': '2016 will smith jared leto red suicide squad it',
#   'answer': {'text': ['suicide squad'], 'answer_start': [31]}},
#  {'question': 'In which year was the movie "Collateral Beauty" with Will Smith released?',
#   'context': 'it 2016 will smith collateral beauty',
#   'answer': {'text': ['2016'], 'answer_start': [3]}},
#  {'question': 'Identify a 2016 film starring Margot Robbie.',
#   'context': 'suicide squad margot robbie 2016 ti argo',
#   'answer': {'text': ['suicide squad'], 'answer_start': [0]}},
#  {'question': 'Name a movie released in 2016 with Chris Pratt in the lead role.',
#   'context': '2016 chris pratt it passengers',
#   'answer': {'text': ['passengers'], 'answer_start': [20]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "Doctor Strange"?',
#   'context': 'ti 2016 doctor strange doctor strange it',
#   'answer': {'text': ['doctor strange'], 'answer_start': [8]}},
#  {'question': 'Which film stars Ryan Gosling and was released in 2016?',
#   'context': 'ryan gosling 2016 la la land',
#   'answer': {'text': ['la la land'], 'answer_start': [18]}},
#  {'question': 'What is the title of the 2016 movie featuring Ben Affleck and Henry Cavill?',
#   'context': 'batman v superman: dawn of justice it 2016 henry cavill ben affleck ti',
#   'answer': {'text': ['batman v superman: dawn of justice'],
#    'answer_start': [0]}},
#  {'question': 'Which 2016 movie stars Emma Stone and Ryan Gosling?',
#   'context': '2016 emma stone ryan gosling la la land',
#   'answer': {'text': ['la la land'], 'answer_start': [29]}},
#  {'question': 'In which year was the movie "The Accountant" with Ben Affleck released?',
#   'context': 'ben affleck the accountant it 2016',
#   'answer': {'text': ['2016'], 'answer_start': [30]}},
#  {'question': 'Identify a film from 2016 that stars Matt Damon.',
#   'context': 'matt damon jason bourne ti 2016',
#   'answer': {'text': ['jason bourne'], 'answer_start': [11]}},
#  {'question': 'Name a 2016 release with Amy Adams as the lead actress.',
#   'context': '2016 amy adams arrival it',
#   'answer': {'text': ['arrival'], 'answer_start': [15]}},
#  {'question': 'Can you mention a 2016 movie with Will Smith in the lead role?',
#   'context': '2016 collateral beauty ti it will smith',
#   'answer': {'text': ['collateral beauty'], 'answer_start': [5]}},
#  {'question': 'What is the title of the film from 2016 featuring Felicity Jones and Diego Luna?',
#   'context': 'felicity jones ti rogue one diego luna it 2016',
#   'answer': {'text': ['rogue one'], 'answer_start': [18]}},
#  {'question': 'Which 2016 movie stars Chris Pratt and Jennifer Lawrence?',
#   'context': '2016 chris pratt passengers jennifer lawrence',
#   'answer': {'text': ['passengers'], 'answer_start': [17]}},
#  {'question': 'In which year was the movie "War Dogs" with Jonah Hill released?',
#   'context': '2016 jonah hill war it war dogs',
#   'answer': {'text': ['2016'], 'answer_start': [0]}},
#  {'question': 'Identify a 2016 film starring Natalie Portman.',
#   'context': 'jackie ti 2016 natalie portman',
#   'answer': {'text': ['jackie'], 'answer_start': [0]}},
#  {'question': 'Name a movie from 2016 with Michael Fassbender in a leading role.',
#   'context': "2016 it assassin's creed michael fassbender",
#   'answer': {'text': ["assassin's creed"], 'answer_start': [8]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "Fantastic Beasts and Where to Find Them"?',
#   'context': 'her fantastic beasts and where to find them ti it 2016 fantastic beasts and where to find them',
#   'answer': {'text': ['fantastic beasts and where to find them'],
#    'answer_start': [4]}},
#  {'question': 'Which film stars Will Smith and Keira Knightley and was released in 2016?',
#   'context': 'collateral beauty will smith it keira knightley 2016',
#   'answer': {'text': ['collateral beauty'], 'answer_start': [0]}},
#  {'question': 'What is the title of the 2016 movie featuring Chris Pine and Zachary Quinto?',
#   'context': 'chris pine zachary quinto it star trek beyond ti 2016',
#   'answer': {'text': ['star trek beyond'], 'answer_start': [29]}},
#  {'question': 'Which 2016 movie stars Hugh Jackman and Taron Egerton?',
#   'context': 'taron egerton hugh jackman eddie the eagle 2016',
#   'answer': {'text': ['eddie the eagle'], 'answer_start': [27]}},
#  {'question': 'In which year was the sci-fi movie "The Martian" starring Matt Damon and Jessica Chastain released?',
#   'context': '2015 the martian matt damon ti jessica chastain',
#   'answer': {'text': ['2015'], 'answer_start': [0]}},
#  {'question': 'Can you name a film from 2014 that features Chris Pratt, Zoe Saldana, and Bradley Cooper?',
#   'context': 'zoe saldana chris pratt 2014 guardians of the galaxy bradley cooper',
#   'answer': {'text': ['guardians of the galaxy'], 'answer_start': [29]}},
#  {'question': 'Which movie from 2016 had a lead cast including Ryan Reynolds, Morena Baccarin, and Ed Skrein?',
#   'context': 'ed skrein deadpool 2016 morena baccarin ryan reynolds',
#   'answer': {'text': ['deadpool'], 'answer_start': [10]}},
#  {'question': 'Identify a 2015 film with Charlize Theron and Tom Hardy in the lead roles.',
#   'context': 'tom hardy mad max: fury road her 2015 it charlize theron ti',
#   'answer': {'text': ['mad max: fury road'], 'answer_start': [10]}},
#  {'question': 'Name a 2016 release where Chris Evans and Robert Downey Jr. share the screen.',
#   'context': 'captain america: civil war robert downey jr chris evans her 2016',
#   'answer': {'text': ['captain america: civil war'], 'answer_start': [0]}},
#  {'question': "What's the title of the 2016 film starring Will Smith and Margot Robbie?",
#   'context': 'ti will smith 2016 it focus margot robbie argo',
#   'answer': {'text': ['focus'], 'answer_start': [22]}},
#  {'question': 'Which 2014 movie featured Matthew McConaughey, Anne Hathaway, and Jessica Chastain?',
#   'context': 'jessica chastain anne hathaway matthew mcconaughey 2014 interstellar red',
#   'answer': {'text': ['interstellar'], 'answer_start': [56]}},
#  {'question': 'Can you mention a 2015 film with Saoirse Ronan, Emory Cohen, and Domhnall Gleeson?',
#   'context': 'it brooklyn 2015 saoirse ronan ti domhnall gleeson emory cohen',
#   'answer': {'text': ['brooklyn'], 'answer_start': [3]}},
#  {'question': 'In which year was the animated movie "Inside Out" with the voices of Amy Poehler and Bill Hader released?',
#   'context': 'inside out 2015 it amy poehler ted bill hader',
#   'answer': {'text': ['2015'], 'answer_start': [11]}},
#  {'question': 'Identify a 2016 film starring Jared Leto and Will Smith.',
#   'context': 'ti 2016 jared leto will smith suicide squad it red',
#   'answer': {'text': ['suicide squad'], 'answer_start': [30]}},
#  {'question': 'Which movie from 2016 featured Ryan Gosling and Russell Crowe as the lead actors?',
#   'context': 'red 2016 russell crowe ryan gosling the nice guys',
#   'answer': {'text': ['the nice guys'], 'answer_start': [36]}},
#  {'question': 'Name a 2015 release with Cate Blanchett and Rooney Mara in the leading roles.',
#   'context': '2015 carol it cate blanchett rooney mara',
#   'answer': {'text': ['carol'], 'answer_start': [5]}},
#  {'question': 'What is the title of the 2016 movie featuring Chris Hemsworth and Charlize Theron?',
#   'context': "it chris hemsworth ti charlize theron her 2016 the huntsman: winter's war",
#   'answer': {'text': ["the huntsman: winter's war"], 'answer_start': [47]}},
#  {'question': 'Can you name a film from 2016 that stars Eddie Redmayne, Katherine Waterston, and Colin Farrell?',
#   'context': 'fantastic beasts and where to find them eddie redmayne katherine waterston red colin farrell her 2016',
#   'answer': {'text': ['fantastic beasts and where to find them'],
#    'answer_start': [0]}},
#  {'question': 'In which year was the action-packed film "X-Men: Apocalypse" with James McAvoy released?',
#   'context': 'action james mcavoy it 2016 ti',
#   'answer': {'text': ['2016'], 'answer_start': [23]}},
#  {'question': 'Which movie from 2016 had a lead cast including Felicity Jones and Diego Luna?',
#   'context': 'rogue one it diego luna 2016 felicity jones',
#   'answer': {'text': ['rogue one'], 'answer_start': [0]}},
#  {'question': 'Identify a 2015 film with Johnny Depp and Joel Edgerton in the lead roles.',
#   'context': 'johnny depp joel edgerton 2015 it black mass ti',
#   'answer': {'text': ['black mass'], 'answer_start': [34]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "Sausage Party"?',
#   'context': 'sausage party sausage party ti 2016 it',
#   'answer': {'text': ['sausage party'], 'answer_start': [0]}},
#  {'question': "What's the title of the 2016 movie starring Meryl Streep and Hugh Grant?",
#   'context': 'it hugh grant ti 2016 meryl streep florence foster jenkins',
#   'answer': {'text': ['florence foster jenkins'], 'answer_start': [35]}},
#  {'question': 'Which 2015 movie stars Matt Damon, Jessica Chastain, and Jeff Daniels?',
#   'context': '2015 matt damon jessica chastain the martian jeff daniels',
#   'answer': {'text': ['the martian'], 'answer_start': [33]}},
#  {'question': 'In which year was the animated film "Zootopia" with Ginnifer Goodwin and Jason Bateman released?',
#   'context': '2016 ginnifer goodwin ted it jason bateman zootopia',
#   'answer': {'text': ['2016'], 'answer_start': [0]}},
#  {'question': 'Can you name a 2015 movie with Chris Hemsworth, Benjamin Walker, and Cillian Murphy in the lead roles?',
#   'context': 'benjamin walker cillian murphy in the heart of the sea chris hemsworth it 2015',
#   'answer': {'text': ['in the heart of the sea'], 'answer_start': [31]}},
#  {'question': 'Which movie from 2016 had a lead cast including Mark Ruffalo, Michael Keaton, and Rachel McAdams?',
#   'context': 'rachel mcadams michael keaton mark ruffalo 2016 spotlight',
#   'answer': {'text': ['spotlight'], 'answer_start': [48]}},
#  {'question': 'Identify a 2016 film starring Will Ferrell and Mark Wahlberg.',
#   'context': "will ferrell mark wahlberg 2016 ti daddy's home",
#   'answer': {'text': ["daddy's home"], 'answer_start': [35]}},
#  {'question': 'Name a 2015 release with Alicia Vikander and Eddie Redmayne in the leading roles.',
#   'context': 'the danish girl it red alicia vikander 2015 eddie redmayne',
#   'answer': {'text': ['the danish girl'], 'answer_start': [0]}},
#  {'question': 'What is the title of the 2016 movie featuring Henry Cavill and Armie Hammer?',
#   'context': 'armie hammer ti 2016 henry cavill it the man from u.n.c.l.e.',
#   'answer': {'text': ['the man from u.n.c.l.e.'], 'answer_start': [37]}},
#  {'question': 'In which year was the science fiction film "Ex Machina" with Domhnall Gleeson released?',
#   'context': 'it ti 2014 ex machina domhnall gleeson',
#   'answer': {'text': ['2014'], 'answer_start': [6]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "The Revenant"?',
#   'context': 'ti the revenant eve the revenant 2016 it',
#   'answer': {'text': ['the revenant'], 'answer_start': [3]}},
#  {'question': 'Which movie from 2015 featured Tom Hardy and Emily Browning as the lead actors?',
#   'context': 'tom hardy red legend 2015 emily browning',
#   'answer': {'text': ['legend'], 'answer_start': [14]}},
#  {'question': 'Identify a 2016 film starring Johnny Depp and Anne Hathaway.',
#   'context': 'anne hathaway johnny depp alice through the looking glass 2016 ti',
#   'answer': {'text': ['alice through the looking glass'],
#    'answer_start': [26]}},
#  {'question': "What's the title of the 2016 movie starring Seth Rogen and Rose Byrne?",
#   'context': 'it ti rose byrne neighbors 2: sorority rising 2016 seth rogen',
#   'answer': {'text': ['neighbors 2: sorority rising'], 'answer_start': [17]}},
#  {'question': 'Which 2016 movie stars Chris Evans and Robert Downey Jr. and also features Scarlett Johansson?',
#   'context': 'chris evans 2016 captain america: civil war robert downey jr scarlett johansson',
#   'answer': {'text': ['captain america: civil war'], 'answer_start': [17]}},
#  {'question': 'In which year was the action-packed film "Captain America: The Winter Soldier" with Chris Evans released?',
#   'context': '2014 chris evans action ti it',
#   'answer': {'text': ['2014'], 'answer_start': [0]}},
#  {'question': 'Can you name a film from 2016 that stars Gerard Butler and Aaron Eckhart?',
#   'context': 'london has fallen gerard butler aaron eckhart 2016',
#   'answer': {'text': ['london has fallen'], 'answer_start': [0]}},
#  {'question': 'Which movie from 2016 had a lead cast including Amy Adams and Jeremy Renner?',
#   'context': 'arrival jeremy renner 2016 amy adams',
#   'answer': {'text': ['arrival'], 'answer_start': [0]}},
#  {'question': 'Identify a 2015 film with Brie Larson and Jacob Tremblay in the lead roles.',
#   'context': 'ti it room jacob tremblay brie larson 2015',
#   'answer': {'text': ['room'], 'answer_start': [6]}},
#  {'question': 'What is the title of the 2016 movie featuring Rachel McAdams and Colin Farrell?',
#   'context': 'it colin farrell rachel mcadams ti 2016 true crimes',
#   'answer': {'text': ['true crimes'], 'answer_start': [40]}},
#  {'question': 'In which year was the romantic drama "The Light Between Oceans" with Alicia Vikander and Michael Fassbender released?',
#   'context': 'alicia vikander drama michael fassbender ti the light between oceans it 2016',
#   'answer': {'text': ['2016'], 'answer_start': [72]}},
#  {'question': 'Can you mention a 2016 release that shares its lead actor with "Zoolander 2"?',
#   'context': 'it zoolander 2 2016 zoolander 2 ti',
#   'answer': {'text': ['zoolander 2'], 'answer_start': [3]}},
#  {'question': 'Which 2015 movie stars Matt Damon and Jessica Chastain and is set in space?',
#   'context': 'matt damon 2015 the martian jessica chastain',
#   'answer': {'text': ['the martian'], 'answer_start': [16]}},
#  {'question': 'In which year was the science fiction film "Elysium" with Matt Damon and Jodie Foster released?',
#   'context': '2013 matt damon it elysium ti jodie foster',
#   'answer': {'text': ['2013'], 'answer_start': [0]}},
#  {'question': 'Can you name a 2016 movie with James McAvoy, Anya Taylor-Joy, and Betty Buckley in the cast?',
#   'context': 'joy james mcavoy split 2016 it',
#   'answer': {'text': ['split'], 'answer_start': [17]}},
#  {'question': 'Which movie from 2016 had a lead cast including Dwayne Johnson, Carla Gugino, and Alexandra Daddario?',
#   'context': 'carla gugino 2016 rio alexandra daddario dwayne johnson san andreas',
#   'answer': {'text': ['san andreas'], 'answer_start': [56]}},
#  {'question': 'Identify a 2014 film starring Chris Pratt and Zoe Saldana.',
#   'context': 'ti zoe saldana guardians of the galaxy chris pratt 2014',
#   'answer': {'text': ['guardians of the galaxy'], 'answer_start': [15]}},
#  {'question': 'Name a 2016 release with Meryl Streep, Hugh Grant, and Simon Helberg in the leading roles.',
#   'context': 'florence foster jenkins simon helberg meryl streep 2016 it hugh grant',
#   'answer': {'text': ['florence foster jenkins'], 'answer_start': [0]}},
#  {'question': 'What is the title of the 2016 movie featuring Matthew McConaughey and Bryce Dallas Howard?',
#   'context': 'bryce dallas howard it war matthew mcconaughey ti 2016 gold',
#   'answer': {'text': ['gold'], 'answer_start': [55]}},
#  {'question': 'In which year was the action-comedy film "Now You See Me 2" with Jesse Eisenberg released?',
#   'context': 'action 2016 now you see me it jesse eisenberg ti now you see me 2 comedy',
#   'answer': {'text': ['2016'], 'answer_start': [7]}},
#  {'question': 'Can you mention a 2015 release that shares its lead actor with "The Revenant"?',
#   'context': 'eve ti the revenant it 2015 the revenant',
#   'answer': {'text': ['the revenant'], 'answer_start': [7]}},
#  {'question': 'Which movie from 2014 featured Shailene Woodley and Ansel Elgort as the lead actors?',
#   'context': 'red the fault in our stars shailene woodley 2014 ansel elgort',
#   'answer': {'text': ['the fault in our stars'], 'answer_start': [4]}},
#  {'question': 'Identify a 2016 film starring Ben Affleck and Anna Kendrick.',
#   'context': 'anna kendrick 2016 ti ben affleck the accountant',
#   'answer': {'text': ['the accountant'], 'answer_start': [34]}},
#  {'question': "What's the title of the 2016 movie starring Ryan Reynolds and Morena Baccarin?",
#   'context': 'deadpool ryan reynolds ti 2016 it morena baccarin',
#   'answer': {'text': ['deadpool'], 'answer_start': [0]}},
#  {'question': 'Which 2015 movie stars Michael Fassbender, Kate Winslet, and Seth Rogen?',
#   'context': 'seth rogen steve jobs kate winslet michael fassbender 2015',
#   'answer': {'text': ['steve jobs'], 'answer_start': [11]}},
#  {'question': 'In which year was the mystery thriller "The Girl on the Train" with Emily Blunt released?',
#   'context': 'mystery thriller the girl on the train it emily blunt 2016',
#   'answer': {'text': ['2016'], 'answer_start': [54]}},
#  {'question': 'Can you name a film from 2016 that stars Chris Hemsworth, Jessica Chastain, and Emily Blunt?',
#   'context': "2016 jessica chastain emily blunt chris hemsworth the huntsman: winter's war",
#   'answer': {'text': ["the huntsman: winter's war"], 'answer_start': [50]}},
#  {'question': 'Which movie from 2016 had a lead cast including Daniel Radcliffe, Paul Dano, and Mary Elizabeth Winstead?',
#   'context': '2016 mary elizabeth winstead paul dano paul daniel radcliffe swiss army man',
#   'answer': {'text': ['swiss army man'], 'answer_start': [61]}},
#  {'question': 'Identify a 2014 film with Scarlett Johansson and Morgan Freeman in the lead roles.',
#   'context': '2014 scarlett johansson ti morgan freeman lucy morgan it',
#   'answer': {'text': ['lucy'], 'answer_start': [42]}},
#  {'question': 'What is the title of the 2016 movie featuring Amy Adams and Jake Gyllenhaal?',
#   'context': 'jake gyllenhaal amy adams ti it 2016 nocturnal animals',
#   'answer': {'text': ['nocturnal animals'], 'answer_start': [37]}},
#  {'question': 'In which year was the animated film "Zootopia" with the voices of Ginnifer Goodwin and Jason Bateman released?',
#   'context': 'jason bateman zootopia ted ginnifer goodwin it 2016',
#   'answer': {'text': ['2016'], 'answer_start': [47]}},
#  {'question': 'Can you mention a 2015 release that shares its lead actor with "Mad Max: Fury Road"?',
#   'context': 'fury it mad max: fury road max 2015 ti',
#   'answer': {'text': ['mad max: fury road'], 'answer_start': [8]}},
#  {'question': 'Which 2016 movie stars Margot Robbie, Jared Leto, and Will Smith?',
#   'context': '2016 margot robbie red suicide squad it will smith argo jared leto',
#   'answer': {'text': ['suicide squad'], 'answer_start': [23]}},
#  {'question': 'In which year did "The Danish Girl" featuring Eddie Redmayne and Alicia Vikander hit the screens?',
#   'context': 'the danish girl red eddie redmayne it 2015 alicia vikander',
#   'answer': {'text': ['2015'], 'answer_start': [38]}},
#  {'question': 'Who played the role of Lisbeth Salander in the movie "The Girl with the Dragon Tattoo" (2011)?',
#   'context': 'rooney mara it the girl with the dragon tattoo 2011',
#   'answer': {'text': ['rooney mara'], 'answer_start': [0]}},
#  {'question': 'Name a 2015 film in which Tom Hanks starred as a lawyer who negotiates the exchange of captured American U-2 pilot Francis Gary Powers for Soviet spy Rudolf Abel.',
#   'context': '2015 spy bridge of spies red ti tom hanks',
#   'answer': {'text': ['bridge of spies'], 'answer_start': [9]}},
#  {'question': 'In which year was a science fiction film released, directed by Christopher Nolan and starring Matthew McConaughey, with a title related to time and space?',
#   'context': 'matthew mcconaughey it her christopher nolan 2014 ti ted',
#   'answer': {'text': ['2014'], 'answer_start': [45]}},
#  {'question': 'Who portrayed the character of Niki Lauda in "Rush," a biographical sports drama film?',
#   'context': 'rush daniel brühl drama sport',
#   'answer': {'text': ['daniel brühl'], 'answer_start': [5]}},
#  {'question': 'Name a 2015 film with a title that refers to a group of seven bounty hunters seeking vengeance.',
#   'context': 'ti up 2015 the hateful eight it eve',
#   'answer': {'text': ['the hateful eight'], 'answer_start': [11]}},
#  {'question': 'In which year was a film set in the post-apocalyptic Australian wasteland, featuring a character named Max, released?',
#   'context': 'max 2015 ti australia',
#   'answer': {'text': ['2015'], 'answer_start': [4]}},
#  {'question': 'Who played the lead role in "The Wolf of Wall Street," a black comedy crime film directed by Martin Scorsese?',
#   'context': 'the wolf of wall street ted leonardo dicaprio ti crime martin scorsese comedy',
#   'answer': {'text': ['leonardo dicaprio'], 'answer_start': [28]}},
#  {'question': 'Name a 2014 film where Benedict Cumberbatch portrayed Alan Turing, a mathematician who cracked the Enigma code during World War II.',
#   'context': 'her ti 2014 the imitation game war benedict cumberbatch',
#   'answer': {'text': ['the imitation game'], 'answer_start': [12]}},
#  {'question': 'In which year did the science fiction film "Lucy," starring Scarlett Johansson, explore the concept of unlocking the full potential of the human mind?',
#   'context': 'ti scarlett johansson lucy 2014',
#   'answer': {'text': ['2014'], 'answer_start': [27]}},
#  {'question': 'Who played the character of a young chef in "Chef," a comedy-drama film written and directed by Jon Favreau?',
#   'context': 'ted drama jon favreau jon favreau it comedy chef',
#   'answer': {'text': ['jon favreau'], 'answer_start': [10]}},
#  {'question': 'Name a 2015 release in which Matt Damon played an astronaut stranded on Mars.',
#   'context': 'the martian tron 2015 matt damon',
#   'answer': {'text': ['the martian'], 'answer_start': [0]}},
#  {'question': 'In which year did the film "Birdman" win the Academy Award for Best Picture and featured Michael Keaton as a washed-up actor?',
#   'context': 'red war 2014 michael keaton up',
#   'answer': {'text': ['2014'], 'answer_start': [8]}},
#  {'question': 'Who portrayed the iconic character of "Mad Max" in the 2015 action film "Mad Max: Fury Road"?',
#   'context': '2015 action fury ti max tom hardy',
#   'answer': {'text': ['tom hardy'], 'answer_start': [24]}},
#  {'question': 'Name a 2016 film starring Emily Blunt as a woman entangled in a Mexican drug cartel.',
#   'context': 'emily blunt 2016 sicario tangled',
#   'answer': {'text': ['sicario'], 'answer_start': [17]}},
#  {'question': 'In which year was "Jurassic World" released, featuring Chris Pratt and Bryce Dallas Howard in a dinosaur theme park adventure?',
#   'context': 'chris pratt war bryce dallas howard adventure 2015 jurassic world',
#   'answer': {'text': ['2015'], 'answer_start': [46]}},
#  {'question': 'Who played the lead role in the 2014 film "Whiplash," a drama about a young drummer and his intense music instructor?',
#   'context': 'drama whiplash 2014 music miles teller',
#   'answer': {'text': ['miles teller'], 'answer_start': [26]}},
#  {'question': 'Name a 2015 movie in which Jennifer Lawrence starred as a woman who invents a mop and builds a business empire.',
#   'context': 'red jennifer lawrence 2015 joy',
#   'answer': {'text': ['joy'], 'answer_start': [27]}},
#  {'question': 'In which year did a biographical drama film featuring Eddie Redmayne as Stephen Hawking and Felicity Jones as his wife, Jane, release?',
#   'context': '2014 drama eddie redmayne it felicity jones red',
#   'answer': {'text': ['2014'], 'answer_start': [0]}},
#  {'question': 'Who portrayed the character of Lisbeth Salander in the 2018 film "The Girl in the Spider\'s Web"?',
#   'context': 'claire foy',
#   'answer': {'text': ['claire foy'], 'answer_start': [0]}}]

# %%
# Generate custom dataset with tokenizers to get tensors
class CustomQADataset(Dataset):
    def __init__(self, data, tokenizer):
        self.data = data
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        context = self.data[idx]['context']
        question = self.data[idx]['question']
        answer = self.data[idx]['answer']

        inputs = self.tokenizer.encode_plus(
            question,
            context,
            add_special_tokens=True,
            return_tensors='pt',
            max_length=128,
            truncation=True,
            padding='max_length',
            return_offsets_mapping=True
        )

        start_positions = answer['answer_start'][0]
        end_positions = answer['answer_start'][0] + len(answer['text'][0])

        return {
            'input_ids': inputs['input_ids'].squeeze(),
            'attention_mask': inputs['attention_mask'].squeeze(),
            'start_positions': start_positions,
            'end_positions': end_positions
        }

# %%
tokenizer = RobertaTokenizerFast.from_pretrained('deepset/roberta-base-squad2')

# %%
final_custom_dataset = CustomQADataset(dataset, tokenizer)

# %% [markdown]
# ### Dataset is ready .. lets begin finetuning LM

# %%
from torch.utils.data import DataLoader

# %%
model = RobertaForQuestionAnswering.from_pretrained('deepset/roberta-base-squad2')

# %%
train_loader = DataLoader(final_custom_dataset, batch_size=16, shuffle=True)

# %%
# iter_train_loader = iter(train_loader)

# # Get the next batch
# for batch in iter_train_loader:
#     for key in batch:
#         print(batch[key])

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5)
criterion = torch.nn.MSELoss()

num_epochs = 30
for epoch in range(num_epochs):
    model.train()
    for batch in train_loader:
        optimizer.zero_grad()
        inputs = {key: batch[key].to(model.device) for key in batch}
        outputs = model(**inputs)
        start_pred = torch.tensor(torch.argmax(outputs.start_logits, dim = 1).to(torch.float), requires_grad=True)
        end_pred = torch.tensor(torch.argmax(outputs.start_logits, dim = 1).to(torch.float), requires_grad=True)
        start_loss = criterion(start_pred, batch['start_positions'].to(torch.float))
        end_loss = criterion(end_pred, batch['end_positions'].to(torch.float))
        loss = start_loss + end_loss
        loss.backward(retain_graph=True)
        optimizer.step()
        print(loss)
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
# Out:
# /tmp/ipykernel_61259/3022915550.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   start_pred = torch.tensor(torch.argmax(outputs.start_logits, dim = 1).to(torch.float), requires_grad=True)
# /tmp/ipykernel_61259/3022915550.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   end_pred = torch.tensor(torch.argmax(outputs.start_logits, dim = 1).to(torch.float), requires_grad=True)
# tensor(1010.1875, grad_fn=<AddBackward0>)
# tensor(1308.2500, grad_fn=<AddBackward0>)
# tensor(1082.1250, grad_fn=<AddBackward0>)
# tensor(827.5625, grad_fn=<AddBackward0>)
# tensor(730.8125, grad_fn=<AddBackward0>)
# tensor(681.6250, grad_fn=<AddBackward0>)
# tensor(820.0625, grad_fn=<AddBackward0>)
# tensor(1749.7500, grad_fn=<AddBackward0>)
# tensor(948.7500, grad_fn=<AddBackward0>)
# tensor(1548.7500, grad_fn=<AddBackward0>)
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# tensor(1303.1875, grad_fn=<AddBackward0>)
# tensor(2364.3125, grad_fn=<AddBackward0>)
# tensor(793.6875, grad_fn=<AddBackward0>)
# tensor(1104.5000, grad_fn=<AddBackward0>)
# tensor(1339.1250, grad_fn=<AddBackward0>)
# tensor(600.8125, grad_fn=<AddBackward0>)
# tensor(987.0625, grad_fn=<AddBackward0>)
# tensor(680.3125, grad_fn=<AddBackward0>)
# tensor(1108.1875, grad_fn=<AddBackward0>)
# tensor(1384.9375, grad_fn=<AddBackward0>)
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# tensor(1338.5000, grad_fn=<AddBackward0>)
# tensor(1052.3750, grad_fn=<AddBackward0>)
# tensor(600.6250, grad_fn=<AddBackward0>)
# tensor(640.4375, grad_fn=<AddBackward0>)
# tensor(694.8750, grad_fn=<AddBackward0>)
# tensor(1199.8750, grad_fn=<AddBackward0>)
# tensor(1113.2500, grad_fn=<AddBackward0>)
# tensor(530.6250, grad_fn=<AddBackward0>)
# tensor(1010.9375, grad_fn=<AddBackward0>)
# tensor(953.3750, grad_fn=<AddBackward0>)
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# tensor(1362.8750, grad_fn=<AddBackward0>)
# tensor(1323.3750, grad_fn=<AddBackward0>)
# tensor(938.5000, grad_fn=<AddBackward0>)
# tensor(1853., grad_fn=<AddBackward0>)
# tensor(1040.1875, grad_fn=<AddBackward0>)
# tensor(1396.1875, grad_fn=<AddBackward0>)
# tensor(876.4375, grad_fn=<AddBackward0>)
# tensor(621.3125, grad_fn=<AddBackward0>)
# tensor(791.8125, grad_fn=<AddBackward0>)
# tensor(643.1875, grad_fn=<AddBackward0>)
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# tensor(987.3125, grad_fn=<AddBackward0>)
# tensor(855.6875, grad_fn=<AddBackward0>)
# tensor(938., grad_fn=<AddBackward0>)
# tensor(655.4375, grad_fn=<AddBackward0>)
# tensor(1926.5625, grad_fn=<AddBackward0>)
# tensor(924.9375, grad_fn=<AddBackward0>)
# tensor(617.6875, grad_fn=<AddBackward0>)
# tensor(1376.0625, grad_fn=<AddBackward0>)
# tensor(1010.5000, grad_fn=<AddBackward0>)
# tensor(553.9375, grad_fn=<AddBackward0>)
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# tensor(852.5625, grad_fn=<AddBackward0>)
# tensor(1240.6875, grad_fn=<AddBackward0>)
# tensor(681.9375, grad_fn=<AddBackward0>)
# tensor(1275.5000, grad_fn=<AddBackward0>)
# tensor(1104.8125, grad_fn=<AddBackward0>)
# tensor(535.7500, grad_fn=<AddBackward0>)
# tensor(1320.5000, grad_fn=<AddBackward0>)
# tensor(1165.2500, grad_fn=<AddBackward0>)
# tensor(1298.2500, grad_fn=<AddBackward0>)
# tensor(1038.3750, grad_fn=<AddBackward0>)
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# tensor(1212.3125, grad_fn=<AddBackward0>)
# tensor(1168.6875, grad_fn=<AddBackward0>)
# tensor(1389.3125, grad_fn=<AddBackward0>)
# tensor(941.5625, grad_fn=<AddBackward0>)
# tensor(829.1250, grad_fn=<AddBackward0>)
# tensor(1249.3125, grad_fn=<AddBackward0>)
# tensor(1255.8750, grad_fn=<AddBackward0>)
# tensor(2089.3125, grad_fn=<AddBackward0>)
# tensor(889.5625, grad_fn=<AddBackward0>)
# tensor(1452.9375, grad_fn=<AddBackward0>)
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# Save finetuned model
model.save_pretrained('fine_tuned_roberta_squad2')
tokenizer.save_pretrained('fine_tuned_roberta_squad2')
# Out:
# ('fine_tuned_roberta_squad2/tokenizer_config.json',
#  'fine_tuned_roberta_squad2/special_tokens_map.json',
#  'fine_tuned_roberta_squad2/vocab.json',
#  'fine_tuned_roberta_squad2/merges.txt',
#  'fine_tuned_roberta_squad2/added_tokens.json',
#  'fine_tuned_roberta_squad2/tokenizer.json')
